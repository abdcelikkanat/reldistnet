# %% [markdown]
# ### Synthetic Network Generation

# %%
import sys
sys.path.insert(0, '..')
import numpy as np
import pickle
import os
from lib.synnetgen import *
# %matplotlib inline
from IPython.display import HTML

# %%
init_z = np.array([[-3, 0], [-2, -1], [-1, 0], [-2, 1], [1, 0], [2,-1], [3, 0], [2, 1]], dtype=np.float)
A = np.diag([1.0001, 1.0003]).astype(dtype=np.float)
A = [A, A, A]
beta = 2
gamma = 4
tau = 2
T = 10
sng = SynNetGen(init_z=init_z, init_beta=beta, init_gamma=gamma, A=A, tau=tau, T=T)

# %%
anim = sng.animate()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
z0 = np.array([[-5, 0], [-4, -1], [-3, 0], [-4, 1], [3, 0], [4,-1], [5, 0], [4, 1]], dtype=np.float)
init_z = [1.2*z0]
N = init_z[0].shape[0]
D = init_z[0].shape[1]

A =  np.diag([1.03, 0.9])
A = [1*A]
#A = np.random.rand(D, D)
#A = A / A.sum(axis=0)
print(A)


beta = 2
gamma = 4
tau = 1
T = 40
sng = SynNetGen(init_z=init_z, init_beta=beta, init_gamma=gamma, A=A, tau=tau, T=T)

anim = sng.animate()
HTML(anim.to_html5_video())
# Out:
# [array([[1.03, 0.  ],
#        [0.  , 0.9 ]])]
# <video width="720" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
